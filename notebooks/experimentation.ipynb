# %% [markdown]
# # Hindi RAG experimentation
# Load, chunk, and inspect the sample Hindi document.

# %%
from pathlib import Path
from src.document_loader import load_document
from src.text_processor import chunk_document

text = load_document(Path('../data/raw/hindi_document.txt'))
chunks = chunk_document(text)
len(chunks), chunks[0].text
